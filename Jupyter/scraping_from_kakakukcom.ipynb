# %%
# !pip install webdriver_manager
# Out:
# Requirement already satisfied: openpyxl in c:\users\tk5de\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in c:\users\tk5de\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
import time
import os
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException, TimeoutException
import pandas as pd
import datetime
import re
import openpyxl

def main(urls):

    # ドライバ準備
    chrome_options = webdriver.ChromeOptions()
    #Program Files (x86)配下のバージョンの低いChromeを参照しに行ってバージョン非対応と怒られたので、新しいバージョンのChromeアプリにPathを通す
    chrome_options.binary_location = r"C:\Program Files\Google\Chrome\Application\chrome.exe" 
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=chrome_options)
    
    all_reviews = []
    try:
        for url in urls:
            
            # アクセス
            print("スクレイピング開始: ", url)
            driver.get("https://review.kakaku.com/review/" + url + "#tab")
            
            # モデル取得
            try:
                model_name = driver.find_element(By.CLASS_NAME, 'p-main_title').find_element(By.TAG_NAME, 'h2').text
            except NoSuchElementException:
                model_name = ""
            print("モデル: ", model_name)
            
            # レビュー抽出
            all_reviews.extend(get_review(driver, model_name))

            # ページング処理
            while True:
                try:
                    # ボタンが存在するかチェック
                    load_more_button = driver.find_element(By.CLASS_NAME, 'arrowNext01')
                    load_more_button.click()
                    
                    # 読み込み待機
                    time.sleep(2)
                    
                    # 取得
                    all_reviews.extend(get_review(driver, model_name))

                except NoSuchElementException:
                    print("スクレイピング完了")
                    break
                except TimeoutException:
                    print("タイムアウト発生")
                    break

    finally:
        driver.quit()
    
    # 不正な文字を削除
    df = pd.DataFrame(all_reviews)
    for column in df.select_dtypes(include=['object']).columns:
        df[column] = df[column].apply(remove_illegal_characters)

    # 保存先ディレクトリの指定と作成
    output_dir = os.path.join(os.getcwd(), '..', 'Output') #1個上の階層にあるOutputフォルダに格納
    os.makedirs(output_dir, exist_ok=True)
    
    # ファイル名生成
    now = datetime.datetime.now()
    file_name = os.path.join(output_dir, 'kakakucom_reviews_{}.xlsx'.format(now.strftime('%Y%m%d_%H%M%S')))

    # 保存    
    df.to_excel(file_name, index=False)
    print("Saved to", file_name)   
    

def get_review(driver, model_name):
    reviews = []
    
    review_elements = driver.find_elements(By.CLASS_NAME, 'reviewBox')
    for elem in review_elements:
        
        # パンくずリスト
        try:
            breadcrumbs = elem.find_element(By.CLASS_NAME, 'breadcrumbs').text
        except NoSuchElementException:
            breadcrumbs = ""
                
        # パンくずリストの最終項目からSKUを取得
        try:
            breadcrumbs_elements = elem.find_elements(By.XPATH, './/p[@class="breadcrumbs"]//a')
            if breadcrumbs_elements:
                breadcrumbs_last = breadcrumbs_elements[-1].text
            else:
                breadcrumbs_last = elem.find_element(By.XPATH, './/p[@class="breadcrumbs"]').text.split(' > ')[-1]
        except NoSuchElementException:
            breadcrumbs_last = ""
        
        # ユーザ名
        try:
            user_name = elem.find_element(By.CLASS_NAME, 'userName').text
        except NoSuchElementException:
            user_name = ""
        
        # レビュー投稿日
        try:
            entry_date = elem.find_element(By.CLASS_NAME, 'entryDate').text
        except NoSuchElementException:
            entry_date = ""
        
        # レビュー本文
        try:
            review_content = elem.find_element(By.CLASS_NAME, 'revEntryCont').text
        except NoSuchElementException:
            review_content = ""
            
        # レーティング
        ratings = {}
        try:
            rating_elements = elem.find_elements(By.XPATH, './/div[@class="revRateBox type2"]//table//tr')
            for rating in rating_elements:
                rating_category = rating.find_element(By.TAG_NAME, 'th').text
                rating_value = rating.find_element(By.TAG_NAME, 'td').text
                ratings[rating_category] = rating_value                
        except NoSuchElementException:
            print("error")
            
        reviews.append({
            "model_name": model_name,
            "model_detail": breadcrumbs_last,
            "breadcrumbs": breadcrumbs,
            "url": driver.current_url,
            "user_name": user_name,
            "entry_date": entry_date,
            "review_content": review_content,
            **ratings
        })
    
    return reviews

# 処理分割用
def chunk_list(lst, chunk_size):
    for i in range(0, len(lst), chunk_size):
        yield lst[i:i + chunk_size]

# 不正文字出力回避用
def remove_illegal_characters(text):
    ILLEGAL_CHARACTERS_RE = re.compile(
        r'[\000-\010]|[\013-\014]|[\016-\037]|[\x00-\x1f\x7f-\x9f]|[\uffff]'
    )
    if isinstance(text, str):
        return ILLEGAL_CHARACTERS_RE.sub("", text)
    return text

url_list = pd.read_excel('../Output/kakakucom_device_lists_20240602_010957.xlsx', index_col=0)
urls = url_list['model_id'].values.tolist()

url_chunks = chunk_list(urls, 10)
for i, url_chunk in enumerate(url_chunks):
    
    # 一時的処理
    if i < 7:
        continue
    
    print(f'{i}回目のファイル出力処理開始')
    main(url_chunk)
    
# urls = [
#     # WRITE ME
#     "M0000001024"
# ]
# main(urls)
# Out:
# 7回目のファイル出力処理開始
# スクレイピング開始:  M0000000944
# モデル:  Redmi Note 10T
# スクレイピング完了
# スクレイピング開始:  M0000000953
# モデル:  Redmi Note 11 Pro 5G
# スクレイピング完了
# スクレイピング開始:  M0000000825
# モデル:  iPhone 12 mini
# スクレイピング完了
# スクレイピング開始:  M0000000920
# モデル:  Xiaomi 11T Pro
# スクレイピング完了
# スクレイピング開始:  M0000000836
# モデル:  AQUOS sense4
# スクレイピング完了
# スクレイピング開始:  M0000000928
# モデル:  AQUOS wish
# スクレイピング完了
# スクレイピング開始:  M0000000674
# モデル:  Xperia 1
# スクレイピング完了
# スクレイピング開始:  M0000000787
# モデル:  Redmi Note 9S
# スクレイピング完了
# スクレイピング開始:  M0000000721
# モデル:  Xperia 5
# スクレイピング完了
# スクレイピング開始:  M0000000947
# モデル:  AQUOS wish2
# スクレイピング完了
# Saved to C:\Users\tk5de\sophia_datascience_root\Python\thesis\github\Jupyter\..\Output\kakakucom_reviews_20240602_094021.xlsx
# 8回目のファイル出力処理開始
# スクレイピング開始:  M0000001021
# モデル:  Galaxy Z Fold5
# スクレイピング完了
# スクレイピング開始:  M0000001073
# モデル:
# スクレイピング完了
# スクレイピング開始:  M0000000782
# モデル:  OPPO Reno3 A
# スクレイピング完了
# スクレイピング開始:  M0000000943
# モデル:  Galaxy A53 5G
# スクレイピング完了
# スクレイピング開始:  M0000001032
# モデル:  TORQUE G06
# スクレイピング完了
# スクレイピング開始:  M0000000679
# モデル:  Galaxy S10
# スクレイピング完了
# スクレイピング開始:  M0000000967
# モデル:  iPhone 14 Pro Max
# スクレイピング完了
# スクレイピング開始:  M0000000933
# モデル:  Redmi Note 11
# スクレイピング完了
# スクレイピング開始:  M0000000942
# モデル:  Galaxy S22 Ultra
# スクレイピング完了
# スクレイピング開始:  M0000000981
# モデル:  Zenfone 9 (RAM 8GBモデル)
# スクレイピング完了
# Saved to C:\Users\tk5de\sophia_datascience_root\Python\thesis\github\Jupyter\..\Output\kakakucom_reviews_20240602_100456.xlsx
# 9回目のファイル出力処理開始
# スクレイピング開始:  M0000000921
# モデル:  Xperia PRO-I
# スクレイピング完了
# スクレイピング開始:  M0000000903
# モデル:  iPhone 13 Pro
# スクレイピング完了
# スクレイピング開始:  M0000000991
# モデル:  Redmi 12C
# スクレイピング完了
# スクレイピング開始:  M0000000697
# モデル:  iPhone 11
# スクレイピング完了
# スクレイピング開始:  M0000000917
# モデル:  Google Pixel 6
# スクレイピング完了
# スクレイピング開始:  M0000000730
# モデル:  AQUOS sense3
# スクレイピング完了
# スクレイピング開始:  M0000000873
# モデル:  Xperia 10 III
# スクレイピング完了
# スクレイピング開始:  M0000000863
# モデル:  Redmi Note 10 Pro
# スクレイピング完了
# スクレイピング開始:  M0000000926
# モデル:  OPPO A55s 5G
# スクレイピング完了
# スクレイピング開始:  M0000000766
# モデル:  Galaxy S20 5G
# スクレイピング完了
# Saved to C:\Users\tk5de\sophia_datascience_root\Python\thesis\github\Jupyter\..\Output\kakakucom_reviews_20240602_101751.xlsx
# 10回目のファイル出力処理開始
# スクレイピング開始:  M0000000702
# モデル:  OPPO Reno A
# スクレイピング完了
# スクレイピング開始:  M0000000771
# モデル:  Xperia 10 II
# スクレイピング完了
# スクレイピング開始:  M0000000820
# モデル:  AQUOS sense5G
# スクレイピング完了
# スクレイピング開始:  M0000001023
# モデル:  Zenfone 10 (RAM 16GBモデル)
# スクレイピング完了
# スクレイピング開始:  M0000000801
# モデル:  Google Pixel 4a
# スクレイピング完了
# スクレイピング開始:  M0000001006
# モデル:  Google Pixel Fold
# スクレイピング完了
# スクレイピング開始:  M0000000848
# モデル:  Redmi 9T
# スクレイピング完了
# スクレイピング開始:  M0000000988
# モデル:  Xiaomi 12T Pro
# スクレイピング完了
# スクレイピング開始:  M0000000676
# モデル:  HUAWEI P30 lite
# スクレイピング完了
# スクレイピング開始:  M0000000891
# モデル:  Redmi Note 10 JE
# スクレイピング完了
# Saved to C:\Users\tk5de\sophia_datascience_root\Python\thesis\github\Jupyter\..\Output\kakakucom_reviews_20240602_103135.xlsx
# 11回目のファイル出力処理開始
# スクレイピング開始:  M0000000896
# モデル:  Google Pixel 5a (5G)
# スクレイピング完了
# スクレイピング開始:  M0000000642
# モデル:  Xperia XZ3
# スクレイピング完了
# スクレイピング開始:  M0000000827
# モデル:  iPhone 12 Pro
# スクレイピング完了
# スクレイピング開始:  M0000000761
# モデル:  AQUOS R5G
# スクレイピング完了
# スクレイピング開始:  M0000000884
# モデル:  Xperia Ace II
# スクレイピング完了
# スクレイピング開始:  M0000000850
# モデル:  OPPO A54 5G
# スクレイピング完了
# スクレイピング開始:  M0000000946
# モデル:  AQUOS R7
# スクレイピング完了
# スクレイピング開始:  M0000001066
# モデル:  ROG Phone 8 Pro Edition
# スクレイピング完了
# スクレイピング開始:  M0000000723
# モデル:  Galaxy Note10+
# スクレイピング完了
# スクレイピング開始:  M0000000843
# モデル:  AQUOS sense4 lite
# スクレイピング完了
# Saved to C:\Users\tk5de\sophia_datascience_root\Python\thesis\github\Jupyter\..\Output\kakakucom_reviews_20240602_104253.xlsx
# 12回目のファイル出力処理開始
# スクレイピング開始:  M0000000816
# モデル:  Galaxy Note20 Ultra 5G
# スクレイピング完了
# スクレイピング開始:  M0000000564
# モデル:  Xperia XZ1
# スクレイピング完了
# スクレイピング開始:  M0000000773
# モデル:  Galaxy A41
# スクレイピング完了
# スクレイピング開始:  M0000000839
# モデル:  OPPO A73
# スクレイピング完了
# スクレイピング開始:  M0000000957
# モデル:  POCO F4 GT
# スクレイピング完了
# スクレイピング開始:  M0000000945
# モデル:  AQUOS sense6s
# スクレイピング完了
# スクレイピング開始:  M0000000880
# モデル:  AQUOS R6
# スクレイピング完了
# スクレイピング開始:  M0000000990
# モデル:  かんたんスマホ3
# スクレイピング完了
# スクレイピング開始:  M0000000553
# モデル:  iPhone 8
# スクレイピング完了
# スクレイピング開始:  M0000000630
# モデル:  iPhone XR
# スクレイピング完了
# Saved to C:\Users\tk5de\sophia_datascience_root\Python\thesis\github\Jupyter\..\Output\kakakucom_reviews_20240602_105531.xlsx
# 13回目のファイル出力処理開始
# スクレイピング開始:  M0000000965
# モデル:  iPhone 14 Plus
# スクレイピング完了
# スクレイピング開始:  M0000000914
# モデル:  らくらくスマートフォン F-52B
# スクレイピング完了
# スクレイピング開始:  M0000000904
# モデル:  iPhone 13 Pro Max
# スクレイピング完了
# スクレイピング開始:  M0000000857
# モデル:  TORQUE 5G
# スクレイピング完了
# スクレイピング開始:  M0000000919
# モデル:  Xiaomi 11T
# スクレイピング完了
# スクレイピング開始:  M0000000737
# モデル:  OPPO A5 2020
# スクレイピング完了
# スクレイピング開始:  M0000000606
# モデル:  Galaxy S9
# スクレイピング完了
# スクレイピング開始:  M0000000869
# モデル:  Galaxy S21 Ultra 5G
# スクレイピング完了
# スクレイピング開始:  M0000000605
# モデル:  HUAWEI P20 lite
# スクレイピング完了
# スクレイピング開始:  M0000000682
# モデル:  TORQUE G04
# スクレイピング完了
# Saved to C:\Users\tk5de\sophia_datascience_root\Python\thesis\github\Jupyter\..\Output\kakakucom_reviews_20240602_110729.xlsx
# 14回目のファイル出力処理開始
# スクレイピング開始:  M0000000733
# モデル:  BASIO4
# スクレイピング完了
# スクレイピング開始:  M0000001049
# モデル:
# スクレイピング完了
# スクレイピング開始:  M0000001018
# モデル:  ROG Phone 7
# スクレイピング完了
# スクレイピング開始:  M0000000640
# モデル:  AQUOS sense2
# スクレイピング完了
# スクレイピング開始:  M0000000822
# モデル:  Google Pixel 5
# スクレイピング完了
# スクレイピング開始:  M0000000971
# モデル:  BASIO active
# スクレイピング完了
# スクレイピング開始:  M0000000968
# モデル:  Galaxy Z Flip4
# スクレイピング完了
# スクレイピング開始:  M0000000989
# モデル:  Android One S10
# スクレイピング完了
# スクレイピング開始:  M0000000893
# モデル:  Zenfone 8 (RAM 8GBモデル)
# スクレイピング完了
# スクレイピング開始:  M0000000829
# モデル:  Galaxy A21
# スクレイピング完了
# Saved to C:\Users\tk5de\sophia_datascience_root\Python\thesis\github\Jupyter\..\Output\kakakucom_reviews_20240602_111700.xlsx
# 15回目のファイル出力処理開始
# スクレイピング開始:  M0000000977
# モデル:  AQUOS sense7 plus
# スクレイピング完了
# スクレイピング開始:  M0000000918
# モデル:  Google Pixel 6 Pro
# スクレイピング完了
# スクレイピング開始:  M0000000536
# モデル:  Xperia XZ Premium
# スクレイピング完了
# スクレイピング開始:  M0000000684
# モデル:  HUAWEI P30 Pro
# スクレイピング完了
# スクレイピング開始:  M0000000670
# モデル:  Google Pixel 3a
# スクレイピング完了
# スクレイピング開始:  M0000000432
# モデル:  iPhone SE (第1世代)
# スクレイピング完了
# スクレイピング開始:  M0000000687
# モデル:  Xperia Ace
# スクレイピング完了
# スクレイピング開始:  M0000000819
# モデル:  Galaxy A51 5G
# スクレイピング完了
# スクレイピング開始:  M0000000480
# モデル:  Xperia XZ
# スクレイピング完了
# スクレイピング開始:  M0000000847
# モデル:  Redmi Note 9T
# スクレイピング完了
# Saved to C:\Users\tk5de\sophia_datascience_root\Python\thesis\github\Jupyter\..\Output\kakakucom_reviews_20240602_113229.xlsx
# 16回目のファイル出力処理開始
# スクレイピング開始:  M0000000680
# モデル:  Galaxy S10+
# スクレイピング完了
# スクレイピング開始:  M0000000673
# モデル:  AQUOS R3
# スクレイピング完了
# スクレイピング開始:  M0000000975
# モデル:  OPPO A77
# スクレイピング完了
# スクレイピング開始:  M0000000631
# モデル:  iPhone XS
# スクレイピング完了
# スクレイピング開始:  M0000000969
# モデル:  Galaxy Z Fold4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 172
#     169     continue
#     171 print(f'{i}回目のファイル出力処理開始')
# --> 172 main(url_chunk)
#
# Cell In[10], line 53, in main(urls)
#      50     time.sleep(2)
#      52     # 取得
# ---> 53     all_reviews.extend(get_review(driver, model_name))
#      55 except NoSuchElementException:
#      56     print("スクレイピング完了")
#
# Cell In[10], line 129, in get_review(driver, model_name)
#     127     for rating in rating_elements:
#     128         rating_category = rating.find_element(By.TAG_NAME, 'th').text
# --> 129         rating_value = rating.find_element(By.TAG_NAME, 'td').text
#     130         ratings[rating_category] = rating_value
#     131 except NoSuchElementException:
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:90, in WebElement.text(self)
#      87 @property
#      88 def text(self) -> str:
#      89     """The text of the element."""
# ---> 90     return self._execute(Command.GET_ELEMENT_TEXT)["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     343     elif "sessionId" not in params:
#     344         params["sessionId"] = self.session_id
# --> 346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
#     348     self.error_handler.check_response(response)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py:300, in RemoteConnection.execute(self, command, params)
#     298 data = utils.dump_json(params)
#     299 url = f"{self._url}{path}"
# --> 300 return self._request(command_info[0], url, body=data)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py:321, in RemoteConnection._request(self, method, url, body)
#     318     body = None
#     320 if self.keep_alive:
# --> 321     response = self._conn.request(method, url, body=body, headers=headers)
#     322     statuscode = response.status
#     323 else:
#
# File ~\anaconda3\lib\site-packages\urllib3\request.py:74, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      71 urlopen_kw["request_url"] = url
#      73 if method in self._encode_url_methods:
# ---> 74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
#      78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~\anaconda3\lib\site-packages\urllib3\request.py:96, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      93 if fields:
#      94     url += "?" + urlencode(fields)
# ---> 96 return self.urlopen(method, url, **extra_kw)
#
# File ~\anaconda3\lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\anaconda3\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\anaconda3\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:
